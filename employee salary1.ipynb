# %%
import pandas as pd

# %%
data =pd.read_csv('/content/adult 3.csv')

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
#        occupation  relationship   race  gender  capital-gain  capital-loss  \
# 0           False         False  False   False         False         False
# 1           False         False  False   False         False         False
# 2           False         False  False   False         False         False
# 3           False         False  False   False         False         False
# 4           False         False  False   False         False         False
# ...           ...           ...    ...     ...           ...           ...
# 48837       False         False  False   False         False         False
# 48838       False         False  False   False         False         False
# 48839       False         False  False   False         False         False
# 48840       False         False  False   False         False         False
# 48841       False         False  False   False         False         False
#
#        hours-per-week  native-country  income
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 48837           False           False   False
# 48838           False           False   False
# 48839           False           False   False
# 48840           False           False   False
# 48841           False           False   False
#
# [48842 rows x 15 columns]

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
data.workclass.replace({'?':'NotListed'},inplace=True)
# Out:
# /tmp/ipython-input-9-2835487482.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.workclass.replace({'?':'NotListed'},inplace=True)

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data=data[data['workclass']!='Without-pay']

# %%
data=data[data['workclass']!='Never-worked']

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# NotListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (48811, 15)

# %%
data=data[data['education']!='1st-4th']

# %%
data=data[data['education']!='11th']

# %%
data.shape
# Out:
# (46755, 15)

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18     NotListed  103497  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4           Never-married                  ?      Own-child  White  Female
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [46755 rows x 15 columns]

# %%
data.drop(columns=['education'],inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18     NotListed  103497               10       Never-married
# 5       34       Private  198693                6       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation   relationship   race  gender  capital-gain  \
# 1        Farming-fishing        Husband  White    Male             0
# 2        Protective-serv        Husband  White    Male             0
# 3      Machine-op-inspct        Husband  Black    Male          7688
# 4                      ?      Own-child  White  Female             0
# 5          Other-service  Not-in-family  White    Male             0
# ...                  ...            ...    ...     ...           ...
# 48837       Tech-support           Wife  White  Female             0
# 48838  Machine-op-inspct        Husband  White    Male             0
# 48839       Adm-clerical      Unmarried  White  Female             0
# 48840       Adm-clerical      Own-child  White    Male             0
# 48841    Exec-managerial           Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country income
# 1                 0              50  United-States  <=50K
# 2                 0              40  United-States   >50K
# 3                 0              40  United-States   >50K
# 4                 0              30  United-States  <=50K
# 5                 0              30  United-States  <=50K
# ...             ...             ...            ...    ...
# 48837             0              38  United-States  <=50K
# 48838             0              40  United-States   >50K
# 48839             0              40  United-States  <=50K
# 48840             0              20  United-States  <=50K
# 48841             0              40  United-States   >50K
#
# [46755 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.show()

# %%
data= data[(data['age']<=75)&(data['age']>=17)]
plt.boxplot(data['age'])
plt.show()

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['workclass']=encoder.fit_transform(data['workclass'])
data['marital-status']=encoder.fit_transform(data['marital-status'])
data['occupation']=encoder.fit_transform(data['occupation'])
data['relationship']=encoder.fit_transform(data['relationship'])
data['race']=encoder.fit_transform(data['race'])
data['gender']=encoder.fit_transform(data['gender'])
data['native-country']=encoder.fit_transform(data['native-country'])
# Out:
# /tmp/ipython-input-23-1824442150.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']=encoder.fit_transform(data['workclass'])
# /tmp/ipython-input-23-1824442150.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status']=encoder.fit_transform(data['marital-status'])
# /tmp/ipython-input-23-1824442150.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['occupation']=encoder.fit_transform(data['occupation'])
# /tmp/ipython-input-23-1824442150.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['relationship']=encoder.fit_transform(data['relationship'])
# /tmp/ipython-input-23-1824442150.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['race']=encoder.fit_transform(data['race'])
# /tmp/ipython-input-23-1824442150.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender']=encoder.fit_transform(data['gender'])
# /tmp/ipython-input-23-1824442150.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['native-country']=encoder.fit_transform(data['native-country'])

# %%
x=data.drop(columns=['income'])#input
y=data['income']#output

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 1       38          3   89814                9               2           5
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           7
# 4       18          2  103497               10               4           0
# 5       34          3  198693                6               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           7
# 48839   58          3  151910                9               6           1
# 48840   22          3  201490                9               4           1
# 48841   52          4  287927                9               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 1                 0     4       1             0             0              50
# 2                 0     4       1             0             0              40
# 3                 0     2       1          7688             0              40
# 4                 3     4       0             0             0              30
# 5                 1     4       1             0             0              30
# ...             ...   ...     ...           ...           ...             ...
# 48837             5     4       0             0             0              38
# 48838             0     4       1             0             0              40
# 48839             4     4       0             0             0              40
# 48840             3     4       1             0             0              20
# 48841             5     4       0         15024             0              40
#
#        native-country
# 1                  39
# 2                  39
# 3                  39
# 4                  39
# 5                  39
# ...               ...
# 48837              39
# 48838              39
# 48839              39
# 48840              39
# 48841              39
#
# [46398 rows x 13 columns]

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 1       38          3   89814                9               2           5
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           7
# 4       18          2  103497               10               4           0
# 5       34          3  198693                6               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           7
# 48839   58          3  151910                9               6           1
# 48840   22          3  201490                9               4           1
# 48841   52          4  287927                9               2           4
#
#        relationship  race  gender  capital-gain  capital-loss  hours-per-week  \
# 1                 0     4       1             0             0              50
# 2                 0     4       1             0             0              40
# 3                 0     2       1          7688             0              40
# 4                 3     4       0             0             0              30
# 5                 1     4       1             0             0              30
# ...             ...   ...     ...           ...           ...             ...
# 48837             5     4       0             0             0              38
# 48838             0     4       1             0             0              40
# 48839             4     4       0             0             0              40
# 48840             3     4       1             0             0              20
# 48841             5     4       0         15024             0              40
#
#        native-country income
# 1                  39  <=50K
# 2                  39   >50K
# 3                  39   >50K
# 4                  39  <=50K
# 5                  39  <=50K
# ...               ...    ...
# 48837              39  <=50K
# 48838              39   >50K
# 48839              39  <=50K
# 48840              39  <=50K
# 48841              39   >50K
#
# [46398 rows x 14 columns]

# %%
print(data['income'].value_counts())
# Out:
# income
# <=50K    34871
# >50K     11527
# Name: count, dtype: int64

# %%
y=encoder.fit_transform(y)
display(y)
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Split the data into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# Initialize and train a Logistic Regression model
model = LogisticRegression(max_iter=1000)
model.fit(xtrain, ytrain)

# Make predictions on the test set
predict2 = model.predict(xtest)

# Calculate and display the accuracy score
accuracy = accuracy_score(ytest, predict2)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.7990301724137931
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
accuracy_score(ytest, predict2)
# Out:
# 0.7990301724137931

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier()
}

results = {}

# %%
for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(y_test, y_pred))
# Out:
# LogisticRegression Accuracy: 0.8171
#               precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89      6978
#            1       0.70      0.45      0.55      2302
#
#     accuracy                           0.82      9280
#    macro avg       0.77      0.70      0.72      9280
# weighted avg       0.81      0.82      0.80      9280
#
# RandomForest Accuracy: 0.8553
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      6978
#            1       0.75      0.63      0.68      2302
#
#     accuracy                           0.86      9280
#    macro avg       0.82      0.78      0.79      9280
# weighted avg       0.85      0.86      0.85      9280
#
# KNN Accuracy: 0.8265
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89      6978
#            1       0.67      0.59      0.63      2302
#
#     accuracy                           0.83      9280
#    macro avg       0.77      0.75      0.76      9280
# weighted avg       0.82      0.83      0.82      9280
#
# SVM Accuracy: 0.8467
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90      6978
#            1       0.76      0.55      0.64      2302
#
#     accuracy                           0.85      9280
#    macro avg       0.81      0.75      0.77      9280
# weighted avg       0.84      0.85      0.84      9280
#
# GradientBoosting Accuracy: 0.8635
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      6978
#            1       0.80      0.60      0.69      2302
#
#     accuracy                           0.86      9280
#    macro avg       0.84      0.78      0.80      9280
# weighted avg       0.86      0.86      0.86      9280

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', GradientBoostingClassifier())])

# %%
  y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

results = {}

for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])

    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name} Accuracy: {acc:.4f}")
# Out:
# LogisticRegression Accuracy: 0.8171
# RandomForest Accuracy: 0.8558
# KNN Accuracy: 0.8265
# SVM Accuracy: 0.8467
# GradientBoosting Accuracy: 0.8635

# %%
import pandas as pd

results_df = pd.DataFrame(list(results.items()), columns=['Model', 'Accuracy'])
results_df.sort_values(by='Accuracy', ascending=False)
# Out:
#                 Model  Accuracy
# 4    GradientBoosting  0.863470
# 1        RandomForest  0.855819
# 3                 SVM  0.846659
# 2                 KNN  0.826509
# 0  LogisticRegression  0.817134

# %%
from matplotlib import pyplot as plt
results_df['Accuracy'].plot(kind='line', figsize=(8, 4), title='Accuracy')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Retrain best model pipeline
best_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier())
])

best_model.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      6978
#            1       0.76      0.63      0.69      2302
#
#     accuracy                           0.86      9280
#    macro avg       0.82      0.78      0.80      9280
# weighted avg       0.85      0.86      0.85      9280

# %%
import joblib

# Save the model to a file
joblib.dump(best_model, 'employee_salary_predictor.pkl')

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %% [markdown]
# # Task
# Create a user interface for the trained machine learning model to allow users to input data and receive predictions.

# %% [markdown]
# ## Prepare the model
#
# ### Subtask:
# Ensure the trained model is saved in a format suitable for deployment (already done with `joblib`).

# %% [markdown]
# ## Create a prediction function
#
# ### Subtask:
# Write a Python function that takes new data (matching the format of your training data) and uses the loaded model to make predictions.

# %% [markdown]
# **Reasoning**:
# Define a function to load the model and make predictions on new data.

# %%
import joblib

def predict_salary(new_data):
    """
    Predicts the salary class for new input data using the saved model.

    Args:
        new_data (dict or pandas.Series): A dictionary or Series containing the input features.

    Returns:
        str: The predicted income class ('>50K' or '<=50K').
    """
    # Load the saved model
    model = joblib.load('employee_salary_predictor.pkl')

    # Convert the input data to a pandas DataFrame
    if isinstance(new_data, dict):
        new_data_df = pd.DataFrame([new_data])
    elif isinstance(new_data, pd.Series):
        new_data_df = pd.DataFrame([new_data.to_dict()])
    else:
        raise ValueError("Input data must be a dictionary or a pandas Series.")

    # Ensure the columns are in the same order as the training data
    # This assumes 'x' dataframe from training is available in the environment
    if 'x' in globals():
        new_data_df = new_data_df[x.columns]
    else:
        # If 'x' is not available, attempt to infer column order or require it
        print("Warning: Training data 'x' not found. Assuming input data column order is correct.")
        # In a real deployment, you would save the column order during training

    # Make prediction
    prediction_encoded = model.predict(new_data_df)

    # Decode the prediction (assuming 0 for <=50K and 1 for >50K based on previous encoding)
    if prediction_encoded[0] == 0:
        return "<=50K"
    elif prediction_encoded[0] == 1:
        return ">50K"
    else:
        return "Unknown"

# %% [markdown]
# ## Choose a framework
#
# ### Subtask:
# Select a Python web framework (like Flask or Streamlit) to build the user interface.

# %% [markdown]
# ## Design the interface
#
# ### Subtask:
# Create the front-end of your application where users can input data.

# %% [markdown]
# **Reasoning**:
# Import the streamlit library and set the title for the application.

# %%
import streamlit as st

st.title("Employee Salary Predictor")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-43-3441417538.py in <cell line: 0>()
# ----> 1 import streamlit as st
#       2
#       3 st.title("Employee Salary Predictor")
#
# ModuleNotFoundError: No module named 'streamlit'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Reasoning**:
# Install the missing streamlit library.

# %%
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.47.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair<6,>=4.0->streamlit) (1.47.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.7.14)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %% [markdown]
# **Reasoning**:
# Import the streamlit library and set the title for the application. Then add input widgets for the features age, workclass, educational-num, marital-status, occupation, relationship, race, gender, capital-gain, capital-loss, hours-per-week, and native-country. Also add a button for prediction.

# %%
import streamlit as st

st.title("Employee Salary Predictor")

# Input widgets for features
age = st.slider("Age", 17, 90, 30)
workclass = st.selectbox("Workclass", ['Private', 'Self-emp-not-inc', 'Local-gov', 'NotListed', 'State-gov', 'Self-emp-inc', 'Federal-gov'])
educational_num = st.number_input("Educational Number", 1, 16, 9)
marital_status = st.selectbox("Marital Status", ['Married-civ-spouse', 'Divorced', 'Never-married', 'Separated', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse'])
occupation = st.selectbox("Occupation", ['?', 'Prof-specialty', 'Craft-repair', 'Exec-managerial', 'Adm-clerical', 'Sales', 'Other-service', 'Machine-op-inspct', 'Transport-moving', 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', 'Armed-Forces'])
relationship = st.selectbox("Relationship", ['Husband', 'Not-in-family', 'Own-child', 'Unmarried', 'Wife', 'Other-relative'])
race = st.selectbox("Race", ['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other'])
gender = st.selectbox("Gender", ['Male', 'Female'])
capital_gain = st.number_input("Capital Gain", 0)
capital_loss = st.number_input("Capital Loss", 0)
hours_per_week = st.slider("Hours per Week", 1, 99, 40)
native_country = st.selectbox("Native Country", ['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico', 'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia', 'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal', 'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala', 'China', 'Japan', 'Yugoslavia', 'Peru', 'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago', 'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary', 'Holand-Netherlands'])

# Prediction button
predict_button = st.button("Predict Salary")

# Section to display prediction result (will be filled in the next subtask)
# Out:
# 2025-07-23 06:20:17.226 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.490
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-07-23 06:20:17.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.537 Session state does not function when running a script without `streamlit run`
# 2025-07-23 06:20:17.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.605 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.633 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.693 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 06:20:17.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Integrate model
#
# ### Subtask:
# Integrate the prediction function with the front-end to display predictions based on user input.

# %% [markdown]
# **Reasoning**:
# The subtask is to integrate the prediction function with the front-end. I will modify the Streamlit script to include the prediction function, collect input data when the predict button is clicked, call the prediction function with the collected data, and display the result.

# %%
import streamlit as st
import joblib
import pandas as pd

def predict_salary(new_data):
    """
    Predicts the salary class for new input data using the saved model.

    Args:
        new_data (dict or pandas.Series): A dictionary or Series containing the input features.

    Returns:
        str: The predicted income class ('>50K' or '<=50K').
    """
    # Load the saved model
    model = joblib.load('employee_salary_predictor.pkl')

    # Convert the input data to a pandas DataFrame
    if isinstance(new_data, dict):
        new_data_df = pd.DataFrame([new_data])
    elif isinstance(new_data, pd.Series):
        new_data_df = pd.DataFrame([new_data.to_dict()])
    else:
        raise ValueError("Input data must be a dictionary or a pandas Series.")

    # Ensure the columns are in the same order as the training data
    # This assumes 'x' dataframe from training is available in the environment
    # A more robust solution would save and load the column order
    # For this example, we will assume the keys in new_data match the order of x.columns
    # If 'x' is not available, this part will need to be adjusted based on how the model was trained
    try:
        # This relies on 'x' being available in the environment, which it is based on the notebook state
        new_data_df = new_data_df[x.columns]
    except NameError:
        st.error("Training data 'x' not found. Cannot ensure correct column order for prediction.")
        return "Error: Training data not available."


    # Make prediction
    prediction_encoded = model.predict(new_data_df)

    # Decode the prediction (assuming 0 for <=50K and 1 for >50K based on previous encoding)
    if prediction_encoded[0] == 0:
        return "<=50K"
    elif prediction_encoded[0] == 1:
        return ">50K"
    else:
        return "Unknown"


st.title("Employee Salary Predictor")

# Input widgets for features
age = st.slider("Age", 17, 90, 30)
workclass = st.selectbox("Workclass", ['Private', 'Self-emp-not-inc', 'Local-gov', 'NotListed', 'State-gov', 'Self-emp-inc', 'Federal-gov'])
educational_num = st.number_input("Educational Number", 1, 16, 9)
marital_status = st.selectbox("Marital Status", ['Married-civ-spouse', 'Divorced', 'Never-married', 'Separated', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse'])
occupation = st.selectbox("Occupation", ['?', 'Prof-specialty', 'Craft-repair', 'Exec-managerial', 'Adm-clerical', 'Sales', 'Other-service', 'Machine-op-inspct', 'Transport-moving', 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', 'Armed-Forces'])
relationship = st.selectbox("Relationship", ['Husband', 'Not-in-family', 'Own-child', 'Unmarried', 'Wife', 'Other-relative'])
race = st.selectbox("Race", ['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other'])
gender = st.selectbox("Gender", ['Male', 'Female'])
capital_gain = st.number_input("Capital Gain", 0)
capital_loss = st.number_input("Capital Loss", 0)
hours_per_week = st.slider("Hours per Week", 1, 99, 40)
native_country = st.selectbox("Native Country", ['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico', 'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia', 'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal', 'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala', 'China', 'Japan', 'Yugoslavia', 'Peru', 'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago', 'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary', 'Holand-Netherlands'])


# Prediction button
predict_button = st.button("Predict Salary")

# Section to display prediction result
if predict_button:
    # Collect input data
    input_data = {
        'age': age,
        'workclass': workclass,
        'fnlwgt': 0, # fnlwgt was dropped but needs a placeholder if included in x during training
        'educational-num': educational_num,
        'marital-status': marital_status,
        'occupation': occupation,
        'relationship': relationship,
        'race': race,
        'gender': gender,
        'capital-gain': capital_gain,
        'capital-loss': capital_loss,
        'hours-per-week': hours_per_week,
        'native-country': native_country
    }

    # Call the prediction function
    # Need to encode categorical features here before passing to predict_salary
    # This requires fitting the encoder on the training data's unique values
    # A more robust solution would save the encoder
    # For this example, we will manually map using unique values from the original data exploration

    # Manual encoding based on observed unique values from notebook
    workclass_map = {val: i for i, val in enumerate(['Private', 'Self-emp-not-inc', 'Local-gov', 'NotListed', 'State-gov', 'Self-emp-inc', 'Federal-gov'])}
    marital_status_map = {val: i for i, val in enumerate(['Married-civ-spouse', 'Divorced', 'Never-married', 'Separated', 'Widowed', 'Married-spouse-absent', 'Married-AF-spouse'])}
    occupation_map = {val: i for i, val in enumerate(['?', 'Prof-specialty', 'Craft-repair', 'Exec-managerial', 'Adm-clerical', 'Sales', 'Other-service', 'Machine-op-inspct', 'Transport-moving', 'Handlers-cleaners', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Priv-house-serv', 'Armed-Forces'])}
    relationship_map = {val: i for i, val in enumerate(['Husband', 'Not-in-family', 'Own-child', 'Unmarried', 'Wife', 'Other-relative'])}
    race_map = {val: i for i, val in enumerate(['White', 'Black', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other'])}
    gender_map = {val: i for i, val in enumerate(['Male', 'Female'])}
    native_country_map = {val: i for i, val in enumerate(['United-States', 'Cuba', 'Jamaica', 'India', '?', 'Mexico', 'South', 'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran', 'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia', 'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal', 'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala', 'China', 'Japan', 'Yugoslavia', 'Peru', 'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago', 'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary', 'Holand-Netherlands'])}


    encoded_input_data = {
        'age': input_data['age'],
        'workclass': workclass_map.get(input_data['workclass'], -1), # Use .get with default -1 for safety
        'fnlwgt': input_data['fnlwgt'],
        'educational-num': input_data['educational-num'],
        'marital-status': marital_status_map.get(input_data['marital-status'], -1),
        'occupation': occupation_map.get(input_data['occupation'], -1),
        'relationship': relationship_map.get(input_data['relationship'], -1),
        'race': race_map.get(input_data['race'], -1),
        'gender': gender_map.get(input_data['gender'], -1),
        'capital-gain': input_data['capital-gain'],
        'capital-loss': input_data['capital-loss'],
        'hours-per-week': input_data['hours-per-week'],
        'native-country': native_country_map.get(input_data['native-country'], -1)
    }


    prediction = predict_salary(encoded_input_data)

    # Display the prediction
    st.success(f"Predicted Salary: {prediction}")

# Remember to save this code to a file named app.py in your Colab environment.
# Out:
# 2025-07-23 07:12:04.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.513 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.524 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.530 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.531 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.539 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.545 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.553 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.555 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.556 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.563 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.566 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.570 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.574 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.576 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.582 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.583 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.585 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.586 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-23 07:12:04.598 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !pip install ngrok


# !ngrok authtoken 30GRE6QF9YOlSGpIPSCgjgBmQL8_5FqFmeWJYobndvrmKdaPG


# !streamlit run app.py &>/dev/null&
# Out:
# Requirement already satisfied: ngrok in /usr/local/lib/python3.11/dist-packages (1.4.0)
# /bin/bash: line 1: ngrok: command not found
